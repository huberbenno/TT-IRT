# %%
import numpy as np
from scipy.sparse import diags_array
from scipy.sparse.linalg import spsolve
import warnings
import matplotlib.pyplot as plt
import tt

class SimplePDE:
  """
  Solve simple diffusion problem on [0,1] using P1 finite elements.
  """

  def __init__(self, N):
    self.N = N
    self.v = 10

  def matrix(self, coeff):
    """
    Assemble components of matrix.
    """

    if len(coeff) != 2:
      raise Exception(f"Wrong number of matrix components ({len(coeff)} != 2).")

    # diffusion component
    [num_coeff, nx, I] = np.shape(coeff[0])
    a = coeff[0][0,:,:]
    A0 = []
    for i in range(I):        
      # assemble A, a piecewise constant on grid
      # linearly dependent on a
      # Ai = np.zeros((self.N+1,self.N+1))
      # Ai.flat[self.N+2::self.N+2] = (a[1:,i] + a[:-1, i]) * self.N # set diag
      # Ai.flat[1::self.N+2] = -a[:,i] * self.N # set first upper diag
      # Ai.flat[self.N+1::self.N+2] = -a[:,i] * self.N # set first lower diag
      # Ai[[0,-1]] = 0 # for dirichlet boundary
      diag_m = np.zeros(self.N + 1)
      diag_m[1:-1] = (a[1:,i] + a[:-1, i]) * self.N
      diag_u = -a[:,i] * self.N
      diag_u[0] = 0
      diag_l = -a[:,i] * self.N
      diag_l[-1] = 0
      Ai = diags_array([diag_m, diag_u, diag_l], offsets=[0, 1, -1], format='csr')
      # Ai = Ai.toarray()
      A0.append(Ai)

    # constant part (from boundary)
    [num_coeff, nx, I] = np.shape(coeff[1])
    A1 = []
    for i in range(I):
      # constant part of matrix
      # Ai = np.zeros((self.N+1,self.N+1))
      # Ai[0,0] = 1
      # Ai[-1,-1] = 1
      
      # convection
      # Ai.flat[1::self.N+2] = self.v # set first upper diag
      # Ai.flat[self.N+1::self.N+2] = -self.v # set first lower diag
      # Ai[0,1] = 0
      # Ai[-1,-2] = 0 # for dirichlet boundary

      diag_m = np.zeros(self.N + 1)
      diag_m[[0,-1]] = 1
      diag_u = np.full(self.N, self.v)
      diag_u[0] = 0
      diag_l = np.full(self.N, -self.v)
      diag_l[-1] = 0
      Ai = diags_array([diag_m, diag_u, diag_l], offsets=[0, 1, -1], format='csr')
      # Ai = Ai.toarray()
      A1.append(Ai)

    return [A0, A1]
  
  def rhs(self, coeff):
    """
    Assemble components of rhs.
    """

    if len(coeff) != 1:
      raise Exception(f"Wrong number of rhs components ({len(coeff)} != 1).")
    
    [num_coeff, nx, I] = np.shape(coeff[0])
    
    # constant rhs
    F0 = []
    for i in range(I):
      # constant part of rhs
      Fi = np.full((self.N+1,1), 10/(self.N)) # assume RHS = 1 
      Fi[[0,-1]] = 0 # boundary condition
      F0.append(Fi)

    return [F0]

  def solve(self, coeff):
    """
    Assemble and solve FE problem for coeff.
    """
    I = np.shape(coeff[0][0])[2]
    
    U = []

    A = self.matrix(coeff[0])
    b = self.rhs(coeff[1])
    for i in range(I):
      U.append(spsolve(A[0][i] + A[1][i], b[0][i]).reshape((-1,1)))

    # for i in range(I):
    #   A = self.matrix([coeff[0][k][:,:,i, np.newaxis] for k in range(len(coeff[0]))])
    #   b = self.rhs([coeff[1][k][:,:,i, np.newaxis] for k in range(len(coeff[1]))])
    #   U.append(np.linalg.solve(A[0][0] + A[1][0], b[0][0]).reshape((-1,1)))
    
    return U

class diffusion_coeff:

  def __init__(self, Nx, Ny, offset, var):
    self.Nx = Nx
    self.Ny = Ny
    self.offset = offset
    self.var = var

  def __call__(self, X):
    c = np.full(len(X), self.offset,dtype=float)
    for i, x in enumerate(X):
      k = np.arange(1,len(x))
      c[i] += np.sum(np.exp(-k) * np.sin(np.pi*k*x[0]/(self.Nx-1)) \
                      * (x[k]/(self.Ny-1) - 0.5) * self.var)
    return np.exp(c)
  
class SymmetricPDE(SimplePDE):
  def __init__(self, N):
    super().__init__(N)

  def matrix(self, coeff):
    res = super().matrix(coeff)
    res[:] = [[0.5*(Aik + Aik.T) for Aik in Ai] for Ai in res]
    # print(np.allclose(res[0][0], res[0][0].T))
    return res

# %% [markdown]
# ### PDE test
#
# Solve the PDE using P1 finite elements for a random parameter

# %%
Nx = 200    # spatial resolution
Ny = 5       # parameter resolution
n_a_param = 5 # number of parameters for diffusion coeff
n_param = n_a_param + 1
offset = 1   # parameter mean
var = 4       # 'variance' of the parameters

# get random params
rng = np.random.default_rng()
y = rng.uniform(0, Ny-1, n_a_param)
X = np.hstack([np.arange(Nx).reshape((-1,1)), np.tile(y, [Nx,1]), np.zeros((Nx,1))])

cfun = diffusion_coeff(Nx, Ny, offset, var)

C_true = cfun(X)

PDE_fun = SimplePDE(Nx)
PDE_fun.v = 20

U = PDE_fun.solve([[C_true.reshape(1,-1,1), np.ones((1,1,1))], [np.ones((1,1,1))]])
U = np.ravel(U[0])

fig, ax = plt.subplots()
ax2 = ax.twinx()

x = np.arange(Nx+1) / Nx
midpoints = (np.arange(Nx) + 0.5) / Nx
p = ax.plot(x, U, label='u')
ax2.fill_between((np.arange(len(C_true)) + 0.5) / (len(C_true)), C_true, alpha=0.2, color=p[0].get_color(), label='C')

ax.set_ylabel('u')
ax.legend(loc='upper left')
ax2.legend(loc='upper right')
ax2.set_ylabel('A')
# Out:
# Text(0, 0.5, 'A')

# %% [markdown]
# ### Get TT approx of coefficient

# %%
from tt import cross

# random init tensor
C_a = tt.rand(np.array([Nx] + [Ny] * n_param),r=3)
# compute TT approx using TT-cross
C_a = tt.cross.rect_cross.cross(cfun, C_a, eps = 1e-8, kickrank=1)
C_a = C_a.round(1e-12)

print("Coefficient ranks: ", C_a.r)
print("Coefficient dims: ", C_a.n)
# Out:
# swp: 0/9 er_rel = 1.2e+01 er_abs = 6.3e+04 erank = 5.1 fun_eval: 2460
# swp: 1/9 er_rel = 7.6e-02 er_abs = 4.3e+02 erank = 7.6 fun_eval: 6935
# swp: 2/9 er_rel = 7.6e-03 er_abs = 4.2e+01 erank = 10.5 fun_eval: 14415
# swp: 3/9 er_rel = 1.1e-02 er_abs = 6.4e+01 erank = 14.9 fun_eval: 27235
# swp: 4/9 er_rel = 1.1e-03 er_abs = 6.0e+00 erank = 19.6 fun_eval: 48720
# swp: 5/9 er_rel = 4.2e-06 er_abs = 2.3e-02 erank = 24.9 fun_eval: 82515
# swp: 6/9 er_rel = 4.4e-08 er_abs = 2.5e-04 erank = 29.7 fun_eval: 131070
# swp: 7/9 er_rel = 1.8e-10 er_abs = 1.0e-06 erank = 34.4 fun_eval: 195630
# Coefficient ranks:  [ 1 34 33 32 29 14  4  1]
# Coefficient dims:  [200   5   5   5   5   5   5]

# %% [markdown]
# ### Test TT approx
#
# Compare TT approx of coefficient $A$ vs the true coefficient $A$ for the random parameter sample from above

# %%
# eval TT-approx of coeff
y = rng.integers(0, Ny, n_a_param)
C_eval = np.empty(Nx)
for i in range(Nx):
  C_eval[i] = C_a[np.concatenate([[i, 0], y])]

X = np.hstack([np.arange(Nx).reshape((-1,1)), np.zeros((Nx,1)), np.tile(y, [Nx,1])])
C_true = cfun(X)

fig, ax = plt.subplots()

x = (np.arange(0, Nx) + .5) / Nx
ax.plot(x, C_eval, label='tt')
ax.plot(x, C_true, ls='dotted', label="reference")
ax.set_xlabel('x')
ax.set_ylabel('A')
ax.legend()

# %%
# helper tensor that is constant 1
cores = [np.ones((1,1,1))]
for i in range(n_param):
  cores += [np.ones((1,Ny,1))]

C_const = tt.vector.from_list(cores)

# %% [markdown]
# ### ALS-cross test

# %%
from als_cross_LSTSQ import als_cross_lstsq as als_cross
# from als_cross import als_cross

test = als_cross(
  [C_a, C_const],
  [C_const],
  PDE_fun,
  1e-8,
  random_init=10,
  kickrank=5
  )

test.iterate(3)
print(test.get_stats())

u = test.get_tensor()

print('Ranks', u.r)
# Out:
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=3.252e-09, rank = [9, 4]
# = swp=2 core <4, dx=1.082e-07, rank = [15, 9]
# = swp=2 core <3, dx=3.102e-06, rank = [19, 15]
# = swp=2 core <2, dx=5.402e-05, rank = [20, 19]
# = swp=2 core <1, dx=5.565e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=5.565e-04, max_rank = 20
# = swp=3 core 1>, dx=8.206e-05, rank = [25, 25]
# = swp=3 core 2>, dx=7.686e-05, rank = [25, 24]
# = swp=3 core 3>, dx=1.261e-05, rank = [24, 19]
# = swp=3 core 4>, dx=4.413e-07, rank = [19, 11]
# = swp=3 core 5>, dx=1.013e-08, rank = [11, 4]
# = swp=3 fwd finish, max_dx=8.206e-05, max_rank = 25
# {'t_solve': 0.009459949913434684, 't_project': 0.16735530400183052, 't_amen': 1.961611325503327, 'n_PDE_eval': 30}
# Ranks [ 1 25 25 24 19 11  4  1]

# %% [markdown]
# ### Test ALS-cross accuracy
#
# Compare ALS cross approximation vs PDE solution for a random sample

# %%
def compute_sample(PDE_fun, u):
  # get random parameter
  y = rng.integers(0, Ny, n_param)
  X = np.hstack([np.arange(Nx).reshape((-1,1)), np.tile(y, [Nx,1])])

  C_a_true = cfun(X) # compute true coeff

  U = PDE_fun.solve([[C_a_true.reshape(1,-1,1), np.zeros((1,1,1))], [np.zeros((1,1,1))]]) # solve PDE
  U = np.ravel(U)

  # eval ALS-cross
  U_eval = np.empty(u.n[0])
  for i in range(u.n[0]):
    U_eval[i] = u[np.concatenate(([i], y))]

  return U, U_eval

def MC_compute_err(PDE_fun, u, N_MC = 500):
  err = 0
  for n in range(N_MC):
    U, U_eval = compute_sample(PDE_fun, u)
    err += np.sum(np.square(U - U_eval))

  return np.sqrt(err / N_MC)

# %%
N_MC = 500
print(f'RMS l2 err = {MC_compute_err(PDE_fun, u, N_MC):.2e}')
# Out:
# RMS l2 err = 7.81e-05

# %%
U, U_eval = compute_sample(PDE_fun, u)

fig, ax = plt.subplots(figsize=(8,3))

x = np.arange(0, Nx+1) / Nx
ax.plot(x, U_eval, label='ALS-cross')
ax.plot(x, U, ls='dashed', label='reference')
ax.set_xlabel('x')
ax.set_ylabel('u')
ax.legend()

# %%
from als_cross_LSTSQ import als_cross_lstsq as als_cross_lstsq
from als_cross import als_cross as als_cross_standard

# random_init_ranks = [10,20,30,40]
# eps_arr = [1e-2, 1e-5, 1e-8]
v_arr = [0,5,10,20,40,60,80,100]

err_standard = []
err_lstsq = []
PDE_fun.v = 10
N_MC = 250
N_attempts = 10
random_init = 10
kickrank = 5
# for random_init in random_init_ranks:
# for eps in eps_arr:
for v in v_arr:
  errs_standard = np.zeros(N_attempts)
  errs_lstsq = np.zeros(N_attempts)
  C_a_round = C_a.round(1e-8)
  # C_a_round = C_a
  PDE_fun.v = v
  for att in range(N_attempts):
    worker = als_cross_standard(
      [C_a_round, C_const],
      [C_const],
      PDE_fun,
      1e-8,
      random_init=random_init,
      kickrank=kickrank
      )
    worker.iterate(3)
    # print(worker.get_stats())
    u_standard = worker.get_tensor()
    errs_standard[att] = MC_compute_err(PDE_fun, u_standard, N_MC)

    worker = als_cross_lstsq(
      [C_a_round, C_const],
      [C_const],
      PDE_fun,
      1e-8,
      random_init=random_init,
      kickrank=kickrank
      )
    worker.iterate(3)
    # print(worker.get_stats())
    u_lstsq = worker.get_tensor()
    errs_lstsq[att] = MC_compute_err(PDE_fun, u_lstsq, N_MC)

  err_standard.append(np.mean(errs_standard))
  err_lstsq.append(np.mean(errs_lstsq))
# Out:
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=2.246e-10, rank = [9, 4]
# = swp=2 core <4, dx=5.863e-09, rank = [18, 9]
# = swp=2 core <3, dx=3.266e-07, rank = [20, 18]
# = swp=2 core <2, dx=4.390e-05, rank = [20, 20]
# = swp=2 core <1, dx=1.009e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=1.009e-03, max_rank = 20
# = swp=3 core 1>, dx=9.999e-06, rank = [25, 25]
# = swp=3 core 2>, dx=2.136e-05, rank = [25, 25]
# = swp=3 core 3>, dx=1.080e-06, rank = [25, 21]
# = swp=3 core 4>, dx=1.230e-08, rank = [21, 10]
# = swp=3 core 5>, dx=1.648e-09, rank = [10, 4]
# = swp=3 fwd finish, max_dx=2.136e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 5]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [5, 1]
# = swp=2 core <5, dx=7.907e-12, rank = [10, 5]
# = swp=2 core <4, dx=7.756e-08, rank = [14, 10]
# = swp=2 core <3, dx=3.396e-06, rank = [18, 14]
# = swp=2 core <2, dx=2.883e-04, rank = [20, 18]
# = swp=2 core <1, dx=1.932e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=1.932e-03, max_rank = 20
# = swp=3 core 1>, dx=2.235e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.372e-04, rank = [25, 23]
# = swp=3 core 3>, dx=2.342e-05, rank = [23, 18]
# = swp=3 core 4>, dx=1.368e-06, rank = [18, 11]
# = swp=3 core 5>, dx=1.732e-08, rank = [11, 4]
# = swp=3 fwd finish, max_dx=2.235e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 13]
# = swp=1 core 4>, dx=1.000e+00, rank = [13, 8]
# = swp=1 core 5>, dx=1.000e+00, rank = [8, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=2.303e-11, rank = [8, 4]
# = swp=2 core <4, dx=2.239e-08, rank = [17, 8]
# = swp=2 core <3, dx=8.415e-07, rank = [20, 17]
# = swp=2 core <2, dx=2.005e-05, rank = [20, 20]
# = swp=2 core <1, dx=1.853e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=1.853e-04, max_rank = 20
# = swp=3 core 1>, dx=6.721e-06, rank = [25, 25]
# = swp=3 core 2>, dx=1.609e-05, rank = [25, 25]
# = swp=3 core 3>, dx=1.353e-06, rank = [25, 21]
# = swp=3 core 4>, dx=1.679e-08, rank = [21, 10]
# = swp=3 core 5>, dx=3.984e-09, rank = [10, 4]
# = swp=3 fwd finish, max_dx=1.609e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 13]
# = swp=1 core 4>, dx=1.000e+00, rank = [13, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 5]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [5, 1]
# = swp=2 core <5, dx=2.889e-11, rank = [10, 5]
# = swp=2 core <4, dx=7.471e-08, rank = [14, 10]
# = swp=2 core <3, dx=7.363e-06, rank = [18, 14]
# = swp=2 core <2, dx=3.640e-04, rank = [20, 18]
# = swp=2 core <1, dx=1.701e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=1.701e-03, max_rank = 20
# = swp=3 core 1>, dx=5.380e-04, rank = [25, 25]
# = swp=3 core 2>, dx=3.163e-04, rank = [25, 23]
# = swp=3 core 3>, dx=6.334e-05, rank = [23, 18]
# = swp=3 core 4>, dx=2.519e-06, rank = [18, 11]
# = swp=3 core 5>, dx=1.750e-08, rank = [11, 4]
# = swp=3 fwd finish, max_dx=5.380e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.724e-10, rank = [10, 4]
# = swp=2 core <4, dx=9.801e-09, rank = [18, 10]
# = swp=2 core <3, dx=5.501e-07, rank = [20, 18]
# = swp=2 core <2, dx=1.908e-05, rank = [20, 20]
# = swp=2 core <1, dx=3.032e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=3.032e-04, max_rank = 20
# = swp=3 core 1>, dx=3.505e-06, rank = [25, 25]
# = swp=3 core 2>, dx=2.539e-05, rank = [25, 25]
# = swp=3 core 3>, dx=1.540e-06, rank = [25, 21]
# = swp=3 core 4>, dx=1.134e-08, rank = [21, 11]
# = swp=3 core 5>, dx=5.015e-10, rank = [11, 4]
# = swp=3 fwd finish, max_dx=2.539e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 12]
# = swp=1 core 5>, dx=1.000e+00, rank = [12, 5]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [5, 1]
# = swp=2 core <5, dx=2.546e-11, rank = [11, 5]
# = swp=2 core <4, dx=1.643e-09, rank = [14, 11]
# = swp=2 core <3, dx=6.051e-06, rank = [18, 14]
# = swp=2 core <2, dx=1.177e-04, rank = [20, 18]
# = swp=2 core <1, dx=1.043e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=1.043e-03, max_rank = 20
# = swp=3 core 1>, dx=1.402e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.022e-04, rank = [25, 23]
# = swp=3 core 3>, dx=2.093e-05, rank = [23, 18]
# = swp=3 core 4>, dx=6.291e-06, rank = [18, 12]
# = swp=3 core 5>, dx=6.920e-09, rank = [12, 4]
# = swp=3 fwd finish, max_dx=1.402e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=3.542e-10, rank = [9, 4]
# = swp=2 core <4, dx=2.452e-09, rank = [18, 9]
# = swp=2 core <3, dx=7.572e-07, rank = [20, 18]
# = swp=2 core <2, dx=2.031e-04, rank = [20, 20]
# = swp=2 core <1, dx=2.809e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=2.809e-04, max_rank = 20
# = swp=3 core 1>, dx=1.305e-05, rank = [25, 25]
# = swp=3 core 2>, dx=2.147e-05, rank = [25, 25]
# = swp=3 core 3>, dx=1.629e-06, rank = [25, 22]
# = swp=3 core 4>, dx=2.001e-08, rank = [22, 10]
# = swp=3 core 5>, dx=2.264e-09, rank = [10, 4]
# = swp=3 fwd finish, max_dx=2.147e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 5]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [5, 1]
# = swp=2 core <5, dx=1.598e-11, rank = [10, 5]
# = swp=2 core <4, dx=1.379e-07, rank = [14, 10]
# = swp=2 core <3, dx=2.739e-06, rank = [17, 14]
# = swp=2 core <2, dx=2.165e-04, rank = [20, 17]
# = swp=2 core <1, dx=8.495e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=1.071e-03, max_rank = 20
# = swp=3 core 1>, dx=8.765e-04, rank = [25, 25]
# = swp=3 core 2>, dx=3.476e-04, rank = [25, 22]
# = swp=3 core 3>, dx=9.837e-05, rank = [22, 18]
# = swp=3 core 4>, dx=5.050e-06, rank = [18, 11]
# = swp=3 core 5>, dx=1.332e-08, rank = [11, 4]
# = swp=3 fwd finish, max_dx=8.765e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.912e-10, rank = [9, 4]
# = swp=2 core <4, dx=2.009e-08, rank = [18, 9]
# = swp=2 core <3, dx=7.662e-07, rank = [20, 18]
# = swp=2 core <2, dx=7.497e-05, rank = [20, 20]
# = swp=2 core <1, dx=3.857e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=3.857e-04, max_rank = 20
# = swp=3 core 1>, dx=6.555e-06, rank = [25, 25]
# = swp=3 core 2>, dx=2.281e-05, rank = [25, 25]
# = swp=3 core 3>, dx=1.980e-06, rank = [25, 20]
# = swp=3 core 4>, dx=1.007e-08, rank = [20, 10]
# = swp=3 core 5>, dx=1.600e-09, rank = [10, 4]
# = swp=3 fwd finish, max_dx=2.281e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 5]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [5, 1]
# = swp=2 core <5, dx=6.948e-12, rank = [10, 5]
# = swp=2 core <4, dx=6.882e-08, rank = [14, 10]
# = swp=2 core <3, dx=1.101e-05, rank = [18, 14]
# = swp=2 core <2, dx=1.613e-04, rank = [20, 18]
# = swp=2 core <1, dx=8.160e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=8.160e-04, max_rank = 20
# = swp=3 core 1>, dx=3.326e-04, rank = [25, 25]
# = swp=3 core 2>, dx=8.936e-05, rank = [25, 23]
# = swp=3 core 3>, dx=2.769e-05, rank = [23, 18]
# = swp=3 core 4>, dx=1.820e-06, rank = [18, 11]
# = swp=3 core 5>, dx=1.480e-08, rank = [11, 4]
# = swp=3 fwd finish, max_dx=3.326e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=3.023e-10, rank = [9, 4]
# = swp=2 core <4, dx=5.916e-09, rank = [18, 9]
# = swp=2 core <3, dx=2.589e-07, rank = [20, 18]
# = swp=2 core <2, dx=3.613e-05, rank = [20, 20]
# = swp=2 core <1, dx=4.256e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=4.256e-04, max_rank = 20
# = swp=3 core 1>, dx=7.442e-06, rank = [25, 25]
# = swp=3 core 2>, dx=1.972e-05, rank = [25, 25]
# = swp=3 core 3>, dx=2.020e-06, rank = [25, 21]
# = swp=3 core 4>, dx=1.249e-08, rank = [21, 10]
# = swp=3 core 5>, dx=2.907e-09, rank = [10, 4]
# = swp=3 fwd finish, max_dx=1.972e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 13]
# = swp=1 core 4>, dx=1.000e+00, rank = [13, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=2.243e-09, rank = [9, 4]
# = swp=2 core <4, dx=2.084e-07, rank = [13, 9]
# = swp=2 core <3, dx=1.178e-05, rank = [18, 13]
# = swp=2 core <2, dx=1.537e-04, rank = [20, 18]
# = swp=2 core <1, dx=1.817e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=1.817e-03, max_rank = 20
# = swp=3 core 1>, dx=2.647e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.809e-04, rank = [25, 23]
# = swp=3 core 3>, dx=3.331e-05, rank = [23, 17]
# = swp=3 core 4>, dx=2.777e-06, rank = [17, 11]
# = swp=3 core 5>, dx=1.360e-08, rank = [11, 4]
# = swp=3 fwd finish, max_dx=2.647e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 13]
# = swp=1 core 4>, dx=1.000e+00, rank = [13, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.524e-10, rank = [9, 4]
# = swp=2 core <4, dx=2.130e-07, rank = [17, 9]
# = swp=2 core <3, dx=5.076e-07, rank = [20, 17]
# = swp=2 core <2, dx=4.526e-05, rank = [20, 20]
# = swp=2 core <1, dx=4.981e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=4.981e-04, max_rank = 20
# = swp=3 core 1>, dx=5.503e-06, rank = [25, 25]
# = swp=3 core 2>, dx=2.159e-05, rank = [25, 25]
# = swp=3 core 3>, dx=8.444e-07, rank = [25, 21]
# = swp=3 core 4>, dx=1.329e-08, rank = [21, 10]
# = swp=3 core 5>, dx=1.347e-09, rank = [10, 4]
# = swp=3 fwd finish, max_dx=2.159e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 2>, dx=1.000e+00, rank = [14, 14]
# = swp=1 core 3>, dx=1.000e+00, rank = [14, 13]
# = swp=1 core 4>, dx=1.000e+00, rank = [13, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.590e-08, rank = [9, 4]
# = swp=2 core <4, dx=2.260e-07, rank = [13, 9]
# = swp=2 core <3, dx=9.538e-06, rank = [16, 13]
# = swp=2 core <2, dx=2.283e-04, rank = [19, 16]
# = swp=2 core <1, dx=1.504e-03, rank = [20, 19]
# = swp=3 core 0, max_dx=1.504e-03, max_rank = 20
# = swp=3 core 1>, dx=1.906e-04, rank = [25, 24]
# = swp=3 core 2>, dx=1.215e-04, rank = [24, 21]
# = swp=3 core 3>, dx=3.643e-05, rank = [21, 17]
# = swp=3 core 4>, dx=2.255e-06, rank = [17, 11]
# = swp=3 core 5>, dx=1.956e-08, rank = [11, 4]
# = swp=3 fwd finish, max_dx=1.906e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=3.063e-10, rank = [10, 4]
# = swp=2 core <4, dx=6.340e-09, rank = [18, 10]
# = swp=2 core <3, dx=1.013e-06, rank = [20, 18]
# = swp=2 core <2, dx=2.025e-05, rank = [20, 20]
# = swp=2 core <1, dx=1.592e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=1.592e-04, max_rank = 20
# = swp=3 core 1>, dx=6.692e-06, rank = [25, 25]
# = swp=3 core 2>, dx=1.466e-05, rank = [25, 25]
# = swp=3 core 3>, dx=2.217e-06, rank = [25, 20]
# = swp=3 core 4>, dx=1.459e-08, rank = [20, 10]
# = swp=3 core 5>, dx=2.879e-09, rank = [10, 4]
# = swp=3 fwd finish, max_dx=1.466e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 11]
# = swp=1 core 5>, dx=1.000e+00, rank = [11, 5]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=2.030e-09, rank = [11, 4]
# = swp=2 core <4, dx=7.922e-09, rank = [15, 11]
# = swp=2 core <3, dx=3.427e-06, rank = [18, 15]
# = swp=2 core <2, dx=2.325e-04, rank = [20, 18]
# = swp=2 core <1, dx=7.198e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=7.198e-04, max_rank = 20
# = swp=3 core 1>, dx=1.993e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.116e-04, rank = [25, 23]
# = swp=3 core 3>, dx=1.765e-05, rank = [23, 19]
# = swp=3 core 4>, dx=1.025e-06, rank = [19, 12]
# = swp=3 core 5>, dx=1.891e-08, rank = [12, 4]
# = swp=3 fwd finish, max_dx=1.993e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 13]
# = swp=1 core 4>, dx=1.000e+00, rank = [13, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=8.865e-10, rank = [9, 4]
# = swp=2 core <4, dx=2.196e-08, rank = [17, 9]
# = swp=2 core <3, dx=1.562e-06, rank = [20, 17]
# = swp=2 core <2, dx=5.554e-05, rank = [20, 20]
# = swp=2 core <1, dx=2.949e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=2.949e-04, max_rank = 20
# = swp=3 core 1>, dx=4.258e-06, rank = [25, 25]
# = swp=3 core 2>, dx=1.743e-05, rank = [25, 25]
# = swp=3 core 3>, dx=9.654e-07, rank = [25, 21]
# = swp=3 core 4>, dx=1.295e-08, rank = [21, 11]
# = swp=3 core 5>, dx=1.271e-09, rank = [11, 4]
# = swp=3 fwd finish, max_dx=1.743e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 11]
# = swp=1 core 5>, dx=1.000e+00, rank = [11, 5]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [5, 1]
# = swp=2 core <5, dx=5.063e-11, rank = [11, 5]
# = swp=2 core <4, dx=9.931e-09, rank = [14, 11]
# = swp=2 core <3, dx=1.042e-05, rank = [17, 14]
# = swp=2 core <2, dx=1.407e-04, rank = [20, 17]
# = swp=2 core <1, dx=1.018e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=1.018e-03, max_rank = 20
# = swp=3 core 1>, dx=1.613e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.360e-04, rank = [25, 22]
# = swp=3 core 3>, dx=2.509e-05, rank = [22, 18]
# = swp=3 core 4>, dx=2.064e-06, rank = [18, 11]
# = swp=3 core 5>, dx=5.953e-09, rank = [11, 4]
# = swp=3 fwd finish, max_dx=1.613e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.392e-10, rank = [9, 4]
# = swp=2 core <4, dx=2.244e-08, rank = [18, 9]
# = swp=2 core <3, dx=4.491e-07, rank = [20, 18]
# = swp=2 core <2, dx=2.674e-05, rank = [20, 20]
# = swp=2 core <1, dx=1.064e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=1.064e-03, max_rank = 20
# = swp=3 core 1>, dx=1.159e-05, rank = [25, 25]
# = swp=3 core 2>, dx=3.246e-05, rank = [25, 25]
# = swp=3 core 3>, dx=1.273e-06, rank = [25, 21]
# = swp=3 core 4>, dx=1.305e-08, rank = [21, 10]
# = swp=3 core 5>, dx=2.532e-09, rank = [10, 4]
# = swp=3 fwd finish, max_dx=3.246e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 11]
# = swp=1 core 5>, dx=1.000e+00, rank = [11, 5]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [5, 1]
# = swp=2 core <5, dx=1.792e-11, rank = [11, 5]
# = swp=2 core <4, dx=1.345e-08, rank = [15, 11]
# = swp=2 core <3, dx=1.302e-06, rank = [18, 15]
# = swp=2 core <2, dx=6.271e-05, rank = [20, 18]
# = swp=2 core <1, dx=1.216e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=1.216e-03, max_rank = 20
# = swp=3 core 1>, dx=2.008e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.038e-04, rank = [25, 23]
# = swp=3 core 3>, dx=2.041e-05, rank = [23, 19]
# = swp=3 core 4>, dx=2.016e-06, rank = [19, 11]
# = swp=3 core 5>, dx=3.098e-09, rank = [11, 4]
# = swp=3 fwd finish, max_dx=2.008e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=4.632e-10, rank = [10, 4]
# = swp=2 core <4, dx=1.480e-08, rank = [17, 10]
# = swp=2 core <3, dx=8.912e-08, rank = [20, 17]
# = swp=2 core <2, dx=2.301e-05, rank = [20, 20]
# = swp=2 core <1, dx=3.805e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=3.805e-04, max_rank = 20
# = swp=3 core 1>, dx=6.466e-06, rank = [25, 25]
# = swp=3 core 2>, dx=4.607e-05, rank = [25, 25]
# = swp=3 core 3>, dx=2.310e-06, rank = [25, 21]
# = swp=3 core 4>, dx=2.550e-08, rank = [21, 11]
# = swp=3 core 5>, dx=8.331e-10, rank = [11, 4]
# = swp=3 fwd finish, max_dx=4.607e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=2.409e-09, rank = [10, 4]
# = swp=2 core <4, dx=1.313e-08, rank = [14, 10]
# = swp=2 core <3, dx=1.163e-05, rank = [17, 14]
# = swp=2 core <2, dx=8.300e-05, rank = [20, 17]
# = swp=2 core <1, dx=1.143e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=1.143e-03, max_rank = 20
# = swp=3 core 1>, dx=1.318e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.395e-04, rank = [25, 22]
# = swp=3 core 3>, dx=4.324e-05, rank = [22, 18]
# = swp=3 core 4>, dx=2.654e-06, rank = [18, 12]
# = swp=3 core 5>, dx=1.053e-08, rank = [12, 4]
# = swp=3 fwd finish, max_dx=1.395e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=4.908e-10, rank = [10, 4]
# = swp=2 core <4, dx=6.889e-09, rank = [17, 10]
# = swp=2 core <3, dx=3.975e-07, rank = [20, 17]
# = swp=2 core <2, dx=2.542e-05, rank = [20, 20]
# = swp=2 core <1, dx=6.724e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=6.724e-04, max_rank = 20
# = swp=3 core 1>, dx=8.499e-06, rank = [25, 25]
# = swp=3 core 2>, dx=3.491e-05, rank = [25, 25]
# = swp=3 core 3>, dx=3.082e-06, rank = [25, 21]
# = swp=3 core 4>, dx=3.771e-08, rank = [21, 10]
# = swp=3 core 5>, dx=5.008e-09, rank = [10, 4]
# = swp=3 fwd finish, max_dx=3.491e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 13]
# = swp=1 core 4>, dx=1.000e+00, rank = [13, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=6.605e-09, rank = [10, 4]
# = swp=2 core <4, dx=1.386e-07, rank = [13, 10]
# = swp=2 core <3, dx=9.861e-06, rank = [17, 13]
# = swp=2 core <2, dx=2.559e-04, rank = [20, 17]
# = swp=2 core <1, dx=2.912e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=2.912e-03, max_rank = 20
# = swp=3 core 1>, dx=1.970e-04, rank = [25, 25]
# = swp=3 core 2>, dx=2.376e-04, rank = [25, 22]
# = swp=3 core 3>, dx=8.793e-05, rank = [22, 17]
# = swp=3 core 4>, dx=1.233e-05, rank = [17, 11]
# = swp=3 core 5>, dx=1.324e-08, rank = [11, 4]
# = swp=3 fwd finish, max_dx=2.376e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=5.439e-10, rank = [9, 4]
# = swp=2 core <4, dx=2.878e-09, rank = [18, 9]
# = swp=2 core <3, dx=2.675e-07, rank = [20, 18]
# = swp=2 core <2, dx=2.771e-05, rank = [20, 20]
# = swp=2 core <1, dx=6.607e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=6.607e-04, max_rank = 20
# = swp=3 core 1>, dx=5.118e-06, rank = [25, 25]
# = swp=3 core 2>, dx=3.019e-05, rank = [25, 25]
# = swp=3 core 3>, dx=1.140e-06, rank = [25, 21]
# = swp=3 core 4>, dx=1.411e-08, rank = [21, 11]
# = swp=3 core 5>, dx=1.145e-09, rank = [11, 4]
# = swp=3 fwd finish, max_dx=3.019e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 5]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [5, 1]
# = swp=2 core <5, dx=3.344e-11, rank = [10, 5]
# = swp=2 core <4, dx=7.824e-08, rank = [15, 10]
# = swp=2 core <3, dx=1.668e-06, rank = [17, 15]
# = swp=2 core <2, dx=1.489e-04, rank = [20, 17]
# = swp=2 core <1, dx=1.402e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=1.452e-03, max_rank = 20
# = swp=3 core 1>, dx=2.965e-04, rank = [25, 25]
# = swp=3 core 2>, dx=2.238e-04, rank = [25, 22]
# = swp=3 core 3>, dx=7.237e-05, rank = [22, 19]
# = swp=3 core 4>, dx=9.032e-07, rank = [19, 11]
# = swp=3 core 5>, dx=1.589e-08, rank = [11, 4]
# = swp=3 fwd finish, max_dx=2.965e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=2.608e-10, rank = [9, 4]
# = swp=2 core <4, dx=3.847e-09, rank = [17, 9]
# = swp=2 core <3, dx=5.775e-07, rank = [20, 17]
# = swp=2 core <2, dx=2.699e-05, rank = [20, 20]
# = swp=2 core <1, dx=8.886e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=8.886e-04, max_rank = 20
# = swp=3 core 1>, dx=5.473e-06, rank = [25, 25]
# = swp=3 core 2>, dx=3.527e-05, rank = [25, 25]
# = swp=3 core 3>, dx=2.199e-06, rank = [25, 21]
# = swp=3 core 4>, dx=2.861e-08, rank = [21, 10]
# = swp=3 core 5>, dx=4.906e-09, rank = [10, 4]
# = swp=3 fwd finish, max_dx=3.527e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=7.688e-09, rank = [10, 4]
# = swp=2 core <4, dx=8.898e-08, rank = [14, 10]
# = swp=2 core <3, dx=2.358e-06, rank = [17, 14]
# = swp=2 core <2, dx=1.754e-04, rank = [20, 17]
# = swp=2 core <1, dx=1.197e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=1.240e-03, max_rank = 20
# = swp=3 core 1>, dx=2.626e-04, rank = [25, 25]
# = swp=3 core 2>, dx=2.609e-04, rank = [25, 22]
# = swp=3 core 3>, dx=4.604e-05, rank = [22, 18]
# = swp=3 core 4>, dx=7.761e-07, rank = [18, 11]
# = swp=3 core 5>, dx=6.013e-09, rank = [11, 4]
# = swp=3 fwd finish, max_dx=2.626e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 8]
# = swp=1 core 5>, dx=1.000e+00, rank = [8, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=3.946e-10, rank = [8, 4]
# = swp=2 core <4, dx=2.001e-08, rank = [18, 8]
# = swp=2 core <3, dx=3.882e-07, rank = [20, 18]
# = swp=2 core <2, dx=1.895e-05, rank = [20, 20]
# = swp=2 core <1, dx=4.156e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=4.156e-04, max_rank = 20
# = swp=3 core 1>, dx=6.015e-06, rank = [25, 25]
# = swp=3 core 2>, dx=2.386e-05, rank = [25, 25]
# = swp=3 core 3>, dx=2.365e-06, rank = [25, 22]
# = swp=3 core 4>, dx=1.613e-08, rank = [22, 10]
# = swp=3 core 5>, dx=5.568e-09, rank = [10, 4]
# = swp=3 fwd finish, max_dx=2.386e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 11]
# = swp=1 core 5>, dx=1.000e+00, rank = [11, 5]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [5, 1]
# = swp=2 core <5, dx=3.206e-11, rank = [11, 5]
# = swp=2 core <4, dx=1.407e-07, rank = [15, 11]
# = swp=2 core <3, dx=2.185e-06, rank = [17, 15]
# = swp=2 core <2, dx=6.021e-05, rank = [20, 17]
# = swp=2 core <1, dx=5.033e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=5.033e-03, max_rank = 20
# = swp=3 core 1>, dx=1.414e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.416e-04, rank = [25, 22]
# = swp=3 core 3>, dx=4.944e-05, rank = [22, 19]
# = swp=3 core 4>, dx=9.335e-07, rank = [19, 11]
# = swp=3 core 5>, dx=1.096e-08, rank = [11, 4]
# = swp=3 fwd finish, max_dx=1.416e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=6.270e-10, rank = [9, 4]
# = swp=2 core <4, dx=5.817e-09, rank = [17, 9]
# = swp=2 core <3, dx=1.638e-07, rank = [20, 17]
# = swp=2 core <2, dx=2.098e-05, rank = [20, 20]
# = swp=2 core <1, dx=3.303e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=3.303e-04, max_rank = 20
# = swp=3 core 1>, dx=1.007e-05, rank = [25, 25]
# = swp=3 core 2>, dx=3.037e-05, rank = [25, 25]
# = swp=3 core 3>, dx=1.535e-06, rank = [25, 21]
# = swp=3 core 4>, dx=1.510e-08, rank = [21, 11]
# = swp=3 core 5>, dx=2.487e-09, rank = [11, 4]
# = swp=3 fwd finish, max_dx=3.037e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 11]
# = swp=1 core 5>, dx=1.000e+00, rank = [11, 5]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [5, 1]
# = swp=2 core <5, dx=1.568e-11, rank = [11, 5]
# = swp=2 core <4, dx=2.673e-09, rank = [14, 11]
# = swp=2 core <3, dx=1.999e-06, rank = [17, 14]
# = swp=2 core <2, dx=1.150e-04, rank = [20, 17]
# = swp=2 core <1, dx=1.247e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=1.252e-03, max_rank = 20
# = swp=3 core 1>, dx=2.649e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.637e-04, rank = [25, 22]
# = swp=3 core 3>, dx=2.807e-05, rank = [22, 18]
# = swp=3 core 4>, dx=9.816e-07, rank = [18, 11]
# = swp=3 core 5>, dx=2.663e-09, rank = [11, 4]
# = swp=3 fwd finish, max_dx=2.649e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 13]
# = swp=1 core 4>, dx=1.000e+00, rank = [13, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.172e-09, rank = [10, 4]
# = swp=2 core <4, dx=2.714e-09, rank = [17, 10]
# = swp=2 core <3, dx=7.000e-07, rank = [20, 17]
# = swp=2 core <2, dx=1.834e-05, rank = [20, 20]
# = swp=2 core <1, dx=4.516e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=4.516e-04, max_rank = 20
# = swp=3 core 1>, dx=3.893e-06, rank = [25, 25]
# = swp=3 core 2>, dx=3.484e-05, rank = [25, 25]
# = swp=3 core 3>, dx=3.534e-06, rank = [25, 21]
# = swp=3 core 4>, dx=4.335e-08, rank = [21, 11]
# = swp=3 core 5>, dx=9.760e-10, rank = [11, 4]
# = swp=3 fwd finish, max_dx=3.484e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 13]
# = swp=1 core 4>, dx=1.000e+00, rank = [13, 11]
# = swp=1 core 5>, dx=1.000e+00, rank = [11, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=2.846e-09, rank = [11, 4]
# = swp=2 core <4, dx=3.437e-09, rank = [14, 11]
# = swp=2 core <3, dx=1.198e-05, rank = [18, 14]
# = swp=2 core <2, dx=3.909e-04, rank = [20, 18]
# = swp=2 core <1, dx=1.704e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=1.704e-03, max_rank = 20
# = swp=3 core 1>, dx=1.927e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.878e-04, rank = [25, 23]
# = swp=3 core 3>, dx=5.394e-05, rank = [23, 18]
# = swp=3 core 4>, dx=8.614e-06, rank = [18, 11]
# = swp=3 core 5>, dx=8.133e-09, rank = [11, 4]
# = swp=3 fwd finish, max_dx=1.927e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=5.254e-10, rank = [10, 4]
# = swp=2 core <4, dx=1.361e-09, rank = [18, 10]
# = swp=2 core <3, dx=5.383e-07, rank = [20, 18]
# = swp=2 core <2, dx=1.615e-05, rank = [20, 20]
# = swp=2 core <1, dx=2.714e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=2.714e-04, max_rank = 20
# = swp=3 core 1>, dx=5.524e-06, rank = [25, 25]
# = swp=3 core 2>, dx=2.419e-05, rank = [25, 25]
# = swp=3 core 3>, dx=1.823e-06, rank = [25, 22]
# = swp=3 core 4>, dx=2.087e-08, rank = [22, 11]
# = swp=3 core 5>, dx=8.646e-10, rank = [11, 4]
# = swp=3 fwd finish, max_dx=2.419e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=6.487e-09, rank = [10, 4]
# = swp=2 core <4, dx=1.892e-08, rank = [14, 10]
# = swp=2 core <3, dx=3.794e-06, rank = [17, 14]
# = swp=2 core <2, dx=7.067e-05, rank = [20, 17]
# = swp=2 core <1, dx=6.248e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=1.419e-03, max_rank = 20
# = swp=3 core 1>, dx=3.123e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.006e-04, rank = [25, 22]
# = swp=3 core 3>, dx=1.516e-05, rank = [22, 18]
# = swp=3 core 4>, dx=1.780e-06, rank = [18, 11]
# = swp=3 core 5>, dx=9.883e-09, rank = [11, 4]
# = swp=3 fwd finish, max_dx=3.123e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 13]
# = swp=1 core 4>, dx=1.000e+00, rank = [13, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=4.623e-10, rank = [10, 4]
# = swp=2 core <4, dx=3.507e-09, rank = [17, 10]
# = swp=2 core <3, dx=3.837e-06, rank = [20, 17]
# = swp=2 core <2, dx=2.708e-05, rank = [20, 20]
# = swp=2 core <1, dx=3.753e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=3.753e-04, max_rank = 20
# = swp=3 core 1>, dx=7.186e-06, rank = [25, 25]
# = swp=3 core 2>, dx=2.142e-05, rank = [25, 25]
# = swp=3 core 3>, dx=1.811e-06, rank = [25, 21]
# = swp=3 core 4>, dx=2.658e-08, rank = [21, 11]
# = swp=3 core 5>, dx=1.392e-09, rank = [11, 4]
# = swp=3 fwd finish, max_dx=2.142e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 13]
# = swp=1 core 4>, dx=1.000e+00, rank = [13, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.920e-09, rank = [9, 4]
# = swp=2 core <4, dx=3.067e-07, rank = [14, 9]
# = swp=2 core <3, dx=4.393e-06, rank = [18, 14]
# = swp=2 core <2, dx=3.187e-04, rank = [20, 18]
# = swp=2 core <1, dx=1.663e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=1.663e-03, max_rank = 20
# = swp=3 core 1>, dx=2.826e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.845e-04, rank = [25, 23]
# = swp=3 core 3>, dx=3.073e-05, rank = [23, 18]
# = swp=3 core 4>, dx=2.780e-06, rank = [18, 11]
# = swp=3 core 5>, dx=2.043e-08, rank = [11, 4]
# = swp=3 fwd finish, max_dx=2.826e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 11]
# = swp=1 core 5>, dx=1.000e+00, rank = [11, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=5.892e-10, rank = [11, 4]
# = swp=2 core <4, dx=7.374e-10, rank = [17, 11]
# = swp=2 core <3, dx=1.798e-07, rank = [20, 17]
# = swp=2 core <2, dx=1.868e-05, rank = [20, 20]
# = swp=2 core <1, dx=4.356e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=4.356e-04, max_rank = 20
# = swp=3 core 1>, dx=1.232e-05, rank = [25, 25]
# = swp=3 core 2>, dx=3.023e-05, rank = [25, 25]
# = swp=3 core 3>, dx=2.063e-06, rank = [25, 21]
# = swp=3 core 4>, dx=2.382e-08, rank = [21, 10]
# = swp=3 core 5>, dx=4.118e-09, rank = [10, 4]
# = swp=3 fwd finish, max_dx=3.023e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 13]
# = swp=1 core 4>, dx=1.000e+00, rank = [13, 8]
# = swp=1 core 5>, dx=1.000e+00, rank = [8, 5]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.910e-09, rank = [8, 4]
# = swp=2 core <4, dx=1.368e-06, rank = [14, 8]
# = swp=2 core <3, dx=1.786e-05, rank = [17, 14]
# = swp=2 core <2, dx=2.151e-04, rank = [20, 17]
# = swp=2 core <1, dx=5.274e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=1.978e-03, max_rank = 20
# = swp=3 core 1>, dx=2.253e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.810e-04, rank = [25, 22]
# = swp=3 core 3>, dx=3.558e-05, rank = [22, 18]
# = swp=3 core 4>, dx=1.123e-06, rank = [18, 10]
# = swp=3 core 5>, dx=2.864e-07, rank = [10, 4]
# = swp=3 fwd finish, max_dx=2.253e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=6.535e-10, rank = [10, 4]
# = swp=2 core <4, dx=1.695e-08, rank = [18, 10]
# = swp=2 core <3, dx=7.682e-07, rank = [20, 18]
# = swp=2 core <2, dx=1.805e-05, rank = [20, 20]
# = swp=2 core <1, dx=3.400e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=3.400e-04, max_rank = 20
# = swp=3 core 1>, dx=9.283e-06, rank = [25, 25]
# = swp=3 core 2>, dx=2.537e-05, rank = [25, 25]
# = swp=3 core 3>, dx=1.573e-06, rank = [25, 22]
# = swp=3 core 4>, dx=1.973e-08, rank = [22, 11]
# = swp=3 core 5>, dx=4.832e-10, rank = [11, 4]
# = swp=3 fwd finish, max_dx=2.537e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=2.883e-09, rank = [10, 4]
# = swp=2 core <4, dx=3.214e-08, rank = [15, 10]
# = swp=2 core <3, dx=3.929e-06, rank = [18, 15]
# = swp=2 core <2, dx=5.499e-05, rank = [20, 18]
# = swp=2 core <1, dx=1.001e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=1.577e-03, max_rank = 20
# = swp=3 core 1>, dx=2.505e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.612e-04, rank = [25, 23]
# = swp=3 core 3>, dx=2.897e-05, rank = [23, 19]
# = swp=3 core 4>, dx=1.080e-06, rank = [19, 11]
# = swp=3 core 5>, dx=5.619e-09, rank = [11, 4]
# = swp=3 fwd finish, max_dx=2.505e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=7.641e-10, rank = [10, 4]
# = swp=2 core <4, dx=6.049e-09, rank = [17, 10]
# = swp=2 core <3, dx=2.446e-07, rank = [20, 17]
# = swp=2 core <2, dx=2.053e-05, rank = [20, 20]
# = swp=2 core <1, dx=3.633e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=3.633e-04, max_rank = 20
# = swp=3 core 1>, dx=1.351e-05, rank = [25, 25]
# = swp=3 core 2>, dx=3.641e-05, rank = [25, 25]
# = swp=3 core 3>, dx=1.826e-06, rank = [25, 21]
# = swp=3 core 4>, dx=3.301e-08, rank = [21, 11]
# = swp=3 core 5>, dx=2.779e-10, rank = [11, 4]
# = swp=3 fwd finish, max_dx=3.641e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=8.099e-09, rank = [10, 4]
# = swp=2 core <4, dx=1.034e-07, rank = [15, 10]
# = swp=2 core <3, dx=3.469e-06, rank = [19, 15]
# = swp=2 core <2, dx=7.870e-05, rank = [20, 19]
# = swp=2 core <1, dx=2.350e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=4.318e-03, max_rank = 20
# = swp=3 core 1>, dx=5.969e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.172e-04, rank = [25, 24]
# = swp=3 core 3>, dx=2.626e-05, rank = [24, 19]
# = swp=3 core 4>, dx=2.004e-06, rank = [19, 11]
# = swp=3 core 5>, dx=1.405e-08, rank = [11, 4]
# = swp=3 fwd finish, max_dx=5.969e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=5.170e-10, rank = [9, 4]
# = swp=2 core <4, dx=1.599e-08, rank = [18, 9]
# = swp=2 core <3, dx=1.925e-07, rank = [20, 18]
# = swp=2 core <2, dx=2.283e-05, rank = [20, 20]
# = swp=2 core <1, dx=2.968e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=2.968e-04, max_rank = 20
# = swp=3 core 1>, dx=7.223e-06, rank = [25, 25]
# = swp=3 core 2>, dx=1.882e-05, rank = [25, 25]
# = swp=3 core 3>, dx=1.275e-06, rank = [25, 22]
# = swp=3 core 4>, dx=1.924e-08, rank = [22, 11]
# = swp=3 core 5>, dx=7.091e-10, rank = [11, 4]
# = swp=3 fwd finish, max_dx=1.882e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=5.536e-09, rank = [10, 4]
# = swp=2 core <4, dx=3.902e-08, rank = [15, 10]
# = swp=2 core <3, dx=2.362e-06, rank = [18, 15]
# = swp=2 core <2, dx=7.264e-05, rank = [20, 18]
# = swp=2 core <1, dx=1.655e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=1.690e-03, max_rank = 20
# = swp=3 core 1>, dx=2.467e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.051e-04, rank = [25, 23]
# = swp=3 core 3>, dx=3.092e-05, rank = [23, 19]
# = swp=3 core 4>, dx=5.933e-07, rank = [19, 11]
# = swp=3 core 5>, dx=1.749e-08, rank = [11, 4]
# = swp=3 fwd finish, max_dx=2.467e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=4.176e-10, rank = [9, 4]
# = swp=2 core <4, dx=1.084e-08, rank = [18, 9]
# = swp=2 core <3, dx=2.609e-07, rank = [20, 18]
# = swp=2 core <2, dx=4.064e-05, rank = [20, 20]
# = swp=2 core <1, dx=3.010e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=3.010e-04, max_rank = 20
# = swp=3 core 1>, dx=7.735e-06, rank = [25, 25]
# = swp=3 core 2>, dx=2.919e-05, rank = [25, 25]
# = swp=3 core 3>, dx=1.012e-06, rank = [25, 22]
# = swp=3 core 4>, dx=1.520e-08, rank = [22, 11]
# = swp=3 core 5>, dx=1.900e-09, rank = [11, 4]
# = swp=3 fwd finish, max_dx=2.919e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=4.590e-09, rank = [10, 4]
# = swp=2 core <4, dx=2.062e-08, rank = [15, 10]
# = swp=2 core <3, dx=2.860e-06, rank = [19, 15]
# = swp=2 core <2, dx=4.018e-05, rank = [20, 19]
# = swp=2 core <1, dx=2.689e-03, rank = [20, 20]
# = swp=3 core 0, max_dx=2.895e-03, max_rank = 20
# = swp=3 core 1>, dx=3.954e-04, rank = [25, 25]
# = swp=3 core 2>, dx=1.302e-04, rank = [25, 24]
# = swp=3 core 3>, dx=7.693e-06, rank = [24, 19]
# = swp=3 core 4>, dx=2.958e-06, rank = [19, 11]
# = swp=3 core 5>, dx=7.127e-09, rank = [11, 4]
# = swp=3 fwd finish, max_dx=3.954e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=5.916e-10, rank = [9, 4]
# = swp=2 core <4, dx=2.251e-08, rank = [18, 9]
# = swp=2 core <3, dx=3.128e-07, rank = [20, 18]
# = swp=2 core <2, dx=3.757e-05, rank = [20, 20]
# = swp=2 core <1, dx=2.310e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=2.310e-04, max_rank = 20
# = swp=3 core 1>, dx=7.364e-06, rank = [25, 25]
# = swp=3 core 2>, dx=2.073e-05, rank = [25, 25]
# = swp=3 core 3>, dx=1.380e-06, rank = [25, 22]
# = swp=3 core 4>, dx=1.248e-08, rank = [22, 10]
# = swp=3 core 5>, dx=2.415e-09, rank = [10, 4]
# = swp=3 fwd finish, max_dx=2.073e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 2>, dx=1.000e+00, rank = [14, 13]
# = swp=1 core 3>, dx=1.000e+00, rank = [13, 12]
# = swp=1 core 4>, dx=1.000e+00, rank = [12, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.098e-08, rank = [9, 4]
# = swp=2 core <4, dx=9.596e-08, rank = [13, 9]
# = swp=2 core <3, dx=5.689e-06, rank = [17, 13]
# = swp=2 core <2, dx=7.558e-05, rank = [19, 17]
# = swp=2 core <1, dx=9.333e-04, rank = [20, 19]
# = swp=3 core 0, max_dx=1.624e-03, max_rank = 20
# = swp=3 core 1>, dx=3.100e-04, rank = [25, 24]
# = swp=3 core 2>, dx=1.428e-04, rank = [24, 22]
# = swp=3 core 3>, dx=1.964e-05, rank = [22, 17]
# = swp=3 core 4>, dx=2.086e-06, rank = [17, 11]
# = swp=3 core 5>, dx=9.837e-09, rank = [11, 4]
# = swp=3 fwd finish, max_dx=3.100e-04, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.937e-09, rank = [9, 4]
# = swp=2 core <4, dx=2.272e-08, rank = [18, 9]
# = swp=2 core <3, dx=9.226e-07, rank = [20, 18]
# = swp=2 core <2, dx=2.037e-05, rank = [20, 20]
# = swp=2 core <1, dx=5.087e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=5.087e-04, max_rank = 20
# = swp=3 core 1>, dx=1.278e-05, rank = [25, 25]
# ...
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=2.296e-10, rank = [9, 4]
# = swp=2 core <4, dx=2.710e-08, rank = [15, 9]
# = swp=2 core <3, dx=1.266e-07, rank = [18, 15]
# = swp=2 core <2, dx=4.906e-06, rank = [20, 18]
# = swp=2 core <1, dx=4.518e-05, rank = [20, 20]
# = swp=3 core 0, max_dx=7.384e-05, max_rank = 20
# = swp=3 core 1>, dx=1.761e-05, rank = [25, 25]
# = swp=3 core 2>, dx=5.555e-06, rank = [25, 23]
# = swp=3 core 3>, dx=9.244e-07, rank = [23, 19]
# = swp=3 core 4>, dx=3.019e-08, rank = [19, 10]
# = swp=3 core 5>, dx=9.326e-10, rank = [10, 4]
# = swp=3 fwd finish, max_dx=1.761e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 8]
# = swp=1 core 5>, dx=1.000e+00, rank = [8, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=2.229e-10, rank = [8, 4]
# = swp=2 core <4, dx=6.720e-08, rank = [16, 8]
# = swp=2 core <3, dx=7.669e-08, rank = [20, 16]
# = swp=2 core <2, dx=6.958e-06, rank = [20, 20]
# = swp=2 core <1, dx=4.307e-05, rank = [20, 20]
# = swp=3 core 0, max_dx=3.184e-04, max_rank = 20
# = swp=3 core 1>, dx=4.761e-06, rank = [25, 25]
# = swp=3 core 2>, dx=5.743e-06, rank = [25, 25]
# = swp=3 core 3>, dx=3.337e-07, rank = [25, 19]
# = swp=3 core 4>, dx=3.036e-08, rank = [19, 9]
# = swp=3 core 5>, dx=5.543e-09, rank = [9, 4]
# = swp=3 fwd finish, max_dx=5.743e-06, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 13]
# = swp=1 core 4>, dx=1.000e+00, rank = [13, 8]
# = swp=1 core 5>, dx=1.000e+00, rank = [8, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.843e-10, rank = [8, 4]
# = swp=2 core <4, dx=1.284e-08, rank = [15, 8]
# = swp=2 core <3, dx=1.180e-07, rank = [18, 15]
# = swp=2 core <2, dx=1.265e-05, rank = [20, 18]
# = swp=2 core <1, dx=1.515e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=1.515e-04, max_rank = 20
# = swp=3 core 1>, dx=1.407e-05, rank = [25, 25]
# = swp=3 core 2>, dx=5.599e-06, rank = [25, 23]
# = swp=3 core 3>, dx=1.310e-06, rank = [23, 19]
# = swp=3 core 4>, dx=7.602e-08, rank = [19, 9]
# = swp=3 core 5>, dx=8.112e-09, rank = [9, 4]
# = swp=3 fwd finish, max_dx=1.407e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 8]
# = swp=1 core 5>, dx=1.000e+00, rank = [8, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.916e-10, rank = [9, 4]
# = swp=2 core <4, dx=3.357e-08, rank = [16, 9]
# = swp=2 core <3, dx=2.414e-07, rank = [20, 16]
# = swp=2 core <2, dx=2.827e-05, rank = [20, 20]
# = swp=2 core <1, dx=9.423e-05, rank = [20, 20]
# = swp=3 core 0, max_dx=9.423e-05, max_rank = 20
# = swp=3 core 1>, dx=4.121e-06, rank = [25, 25]
# = swp=3 core 2>, dx=3.542e-06, rank = [25, 25]
# = swp=3 core 3>, dx=3.247e-07, rank = [25, 20]
# = swp=3 core 4>, dx=1.571e-08, rank = [20, 9]
# = swp=3 core 5>, dx=2.515e-09, rank = [9, 4]
# = swp=3 fwd finish, max_dx=4.121e-06, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 13]
# = swp=1 core 4>, dx=1.000e+00, rank = [13, 7]
# = swp=1 core 5>, dx=1.000e+00, rank = [7, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=2.133e-10, rank = [7, 4]
# = swp=2 core <4, dx=5.941e-08, rank = [14, 7]
# = swp=2 core <3, dx=1.236e-06, rank = [18, 14]
# = swp=2 core <2, dx=4.421e-06, rank = [20, 18]
# = swp=2 core <1, dx=3.342e-05, rank = [20, 20]
# = swp=3 core 0, max_dx=2.462e-04, max_rank = 20
# = swp=3 core 1>, dx=2.035e-05, rank = [25, 25]
# = swp=3 core 2>, dx=7.137e-06, rank = [25, 23]
# = swp=3 core 3>, dx=1.160e-06, rank = [23, 18]
# = swp=3 core 4>, dx=6.774e-08, rank = [18, 9]
# = swp=3 core 5>, dx=9.260e-08, rank = [9, 4]
# = swp=3 fwd finish, max_dx=2.035e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 3>, dx=1.000e+00, rank = [14, 13]
# = swp=1 core 4>, dx=1.000e+00, rank = [13, 8]
# = swp=1 core 5>, dx=1.000e+00, rank = [8, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.568e-09, rank = [9, 4]
# = swp=2 core <4, dx=1.277e-08, rank = [15, 9]
# = swp=2 core <3, dx=4.547e-07, rank = [19, 15]
# = swp=2 core <2, dx=1.143e-05, rank = [20, 19]
# = swp=2 core <1, dx=8.825e-05, rank = [20, 20]
# = swp=3 core 0, max_dx=8.825e-05, max_rank = 20
# = swp=3 core 1>, dx=5.095e-06, rank = [25, 25]
# = swp=3 core 2>, dx=4.290e-06, rank = [25, 24]
# = swp=3 core 3>, dx=3.703e-07, rank = [24, 19]
# = swp=3 core 4>, dx=2.027e-08, rank = [19, 9]
# = swp=3 core 5>, dx=3.032e-09, rank = [9, 4]
# = swp=3 fwd finish, max_dx=5.095e-06, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=2.025e-10, rank = [9, 4]
# = swp=2 core <4, dx=3.852e-09, rank = [15, 9]
# = swp=2 core <3, dx=5.912e-08, rank = [18, 15]
# = swp=2 core <2, dx=4.709e-06, rank = [20, 18]
# = swp=2 core <1, dx=7.150e-05, rank = [20, 20]
# = swp=3 core 0, max_dx=1.079e-04, max_rank = 20
# = swp=3 core 1>, dx=1.733e-05, rank = [25, 25]
# = swp=3 core 2>, dx=6.983e-06, rank = [25, 23]
# = swp=3 core 3>, dx=1.135e-06, rank = [23, 18]
# = swp=3 core 4>, dx=4.460e-08, rank = [18, 9]
# = swp=3 core 5>, dx=1.953e-09, rank = [9, 4]
# = swp=3 fwd finish, max_dx=1.733e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 8]
# = swp=1 core 5>, dx=1.000e+00, rank = [8, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=2.234e-10, rank = [9, 4]
# = swp=2 core <4, dx=5.407e-09, rank = [16, 9]
# = swp=2 core <3, dx=8.197e-07, rank = [20, 16]
# = swp=2 core <2, dx=4.874e-06, rank = [20, 20]
# = swp=2 core <1, dx=4.026e-05, rank = [20, 20]
# = swp=3 core 0, max_dx=1.000e-04, max_rank = 20
# = swp=3 core 1>, dx=1.337e-05, rank = [25, 25]
# = swp=3 core 2>, dx=3.806e-06, rank = [25, 25]
# = swp=3 core 3>, dx=4.395e-07, rank = [25, 20]
# = swp=3 core 4>, dx=1.882e-08, rank = [20, 9]
# = swp=3 core 5>, dx=3.259e-09, rank = [9, 4]
# = swp=3 fwd finish, max_dx=1.337e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=3.903e-10, rank = [9, 4]
# = swp=2 core <4, dx=4.066e-09, rank = [14, 9]
# = swp=2 core <3, dx=1.814e-07, rank = [18, 14]
# = swp=2 core <2, dx=3.224e-06, rank = [20, 18]
# = swp=2 core <1, dx=4.647e-05, rank = [20, 20]
# = swp=3 core 0, max_dx=1.716e-04, max_rank = 20
# = swp=3 core 1>, dx=1.621e-05, rank = [25, 25]
# = swp=3 core 2>, dx=6.702e-06, rank = [25, 23]
# = swp=3 core 3>, dx=9.428e-07, rank = [23, 18]
# = swp=3 core 4>, dx=1.076e-07, rank = [18, 9]
# = swp=3 core 5>, dx=2.476e-09, rank = [9, 4]
# = swp=3 fwd finish, max_dx=1.621e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 8]
# = swp=1 core 5>, dx=1.000e+00, rank = [8, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=3.171e-10, rank = [9, 4]
# = swp=2 core <4, dx=2.457e-08, rank = [17, 9]
# = swp=2 core <3, dx=1.394e-07, rank = [20, 17]
# = swp=2 core <2, dx=6.016e-06, rank = [20, 20]
# = swp=2 core <1, dx=9.897e-05, rank = [20, 20]
# = swp=3 core 0, max_dx=9.897e-05, max_rank = 20
# = swp=3 core 1>, dx=6.920e-06, rank = [25, 25]
# = swp=3 core 2>, dx=5.199e-06, rank = [25, 25]
# = swp=3 core 3>, dx=3.771e-07, rank = [25, 21]
# = swp=3 core 4>, dx=1.007e-08, rank = [21, 9]
# = swp=3 core 5>, dx=3.044e-09, rank = [9, 4]
# = swp=3 fwd finish, max_dx=6.920e-06, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 8]
# = swp=1 core 5>, dx=1.000e+00, rank = [8, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.774e-10, rank = [8, 4]
# = swp=2 core <4, dx=8.038e-09, rank = [15, 8]
# = swp=2 core <3, dx=2.223e-07, rank = [18, 15]
# = swp=2 core <2, dx=5.888e-06, rank = [20, 18]
# = swp=2 core <1, dx=7.629e-05, rank = [20, 20]
# = swp=3 core 0, max_dx=1.423e-04, max_rank = 20
# = swp=3 core 1>, dx=1.231e-05, rank = [25, 25]
# = swp=3 core 2>, dx=4.644e-06, rank = [25, 23]
# = swp=3 core 3>, dx=1.375e-06, rank = [23, 18]
# = swp=3 core 4>, dx=8.836e-08, rank = [18, 9]
# = swp=3 core 5>, dx=3.127e-09, rank = [9, 4]
# = swp=3 fwd finish, max_dx=1.231e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 8]
# = swp=1 core 5>, dx=1.000e+00, rank = [8, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.632e-10, rank = [9, 4]
# = swp=2 core <4, dx=1.733e-08, rank = [17, 9]
# = swp=2 core <3, dx=7.291e-08, rank = [20, 17]
# = swp=2 core <2, dx=1.276e-06, rank = [20, 20]
# = swp=2 core <1, dx=6.212e-05, rank = [20, 20]
# = swp=3 core 0, max_dx=1.005e-04, max_rank = 20
# = swp=3 core 1>, dx=5.618e-06, rank = [25, 25]
# = swp=3 core 2>, dx=3.661e-06, rank = [25, 25]
# = swp=3 core 3>, dx=2.185e-07, rank = [25, 20]
# = swp=3 core 4>, dx=1.567e-08, rank = [20, 9]
# = swp=3 core 5>, dx=3.192e-09, rank = [9, 4]
# = swp=3 fwd finish, max_dx=5.618e-06, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 8]
# = swp=1 core 5>, dx=1.000e+00, rank = [8, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.726e-10, rank = [8, 4]
# = swp=2 core <4, dx=7.811e-09, rank = [15, 8]
# = swp=2 core <3, dx=1.037e-07, rank = [18, 15]
# = swp=2 core <2, dx=2.687e-06, rank = [20, 18]
# = swp=2 core <1, dx=2.758e-05, rank = [20, 20]
# = swp=3 core 0, max_dx=6.770e-05, max_rank = 20
# = swp=3 core 1>, dx=1.185e-05, rank = [25, 25]
# = swp=3 core 2>, dx=5.283e-06, rank = [25, 23]
# = swp=3 core 3>, dx=9.743e-07, rank = [23, 19]
# = swp=3 core 4>, dx=1.043e-07, rank = [19, 9]
# = swp=3 core 5>, dx=1.902e-08, rank = [9, 4]
# = swp=3 fwd finish, max_dx=1.185e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 3>, dx=1.000e+00, rank = [14, 13]
# = swp=1 core 4>, dx=1.000e+00, rank = [13, 8]
# = swp=1 core 5>, dx=1.000e+00, rank = [8, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=7.264e-10, rank = [9, 4]
# = swp=2 core <4, dx=1.979e-08, rank = [16, 9]
# = swp=2 core <3, dx=2.961e-07, rank = [19, 16]
# = swp=2 core <2, dx=4.551e-06, rank = [20, 19]
# = swp=2 core <1, dx=4.181e-05, rank = [20, 20]
# = swp=3 core 0, max_dx=1.423e-04, max_rank = 20
# = swp=3 core 1>, dx=6.599e-06, rank = [25, 25]
# = swp=3 core 2>, dx=4.039e-06, rank = [25, 24]
# = swp=3 core 3>, dx=3.543e-07, rank = [24, 20]
# = swp=3 core 4>, dx=1.990e-08, rank = [20, 9]
# = swp=3 core 5>, dx=2.980e-09, rank = [9, 4]
# = swp=3 fwd finish, max_dx=6.599e-06, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 10]
# = swp=1 core 5>, dx=1.000e+00, rank = [10, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=3.772e-10, rank = [9, 4]
# = swp=2 core <4, dx=3.402e-09, rank = [15, 9]
# = swp=2 core <3, dx=1.238e-07, rank = [18, 15]
# = swp=2 core <2, dx=4.243e-06, rank = [20, 18]
# = swp=2 core <1, dx=1.284e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=1.284e-04, max_rank = 20
# = swp=3 core 1>, dx=1.081e-05, rank = [25, 25]
# = swp=3 core 2>, dx=5.988e-06, rank = [25, 23]
# = swp=3 core 3>, dx=1.042e-06, rank = [23, 18]
# = swp=3 core 4>, dx=4.446e-08, rank = [18, 9]
# = swp=3 core 5>, dx=1.694e-09, rank = [9, 4]
# = swp=3 fwd finish, max_dx=1.081e-05, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=3.831e-10, rank = [9, 4]
# = swp=2 core <4, dx=2.216e-09, rank = [16, 9]
# = swp=2 core <3, dx=4.973e-08, rank = [20, 16]
# = swp=2 core <2, dx=4.050e-06, rank = [20, 20]
# = swp=2 core <1, dx=4.605e-05, rank = [20, 20]
# = swp=3 core 0, max_dx=1.366e-04, max_rank = 20
# = swp=3 core 1>, dx=6.673e-06, rank = [25, 25]
# = swp=3 core 2>, dx=4.313e-06, rank = [25, 25]
# = swp=3 core 3>, dx=3.813e-07, rank = [25, 19]
# = swp=3 core 4>, dx=1.624e-08, rank = [19, 9]
# = swp=3 core 5>, dx=2.674e-09, rank = [9, 4]
# = swp=3 fwd finish, max_dx=6.673e-06, max_rank = 25
# = swp=1 core 0, max_dx=1.000e+00, max_rank = 10
# = swp=1 core 1>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 2>, dx=1.000e+00, rank = [15, 15]
# = swp=1 core 3>, dx=1.000e+00, rank = [15, 14]
# = swp=1 core 4>, dx=1.000e+00, rank = [14, 9]
# = swp=1 core 5>, dx=1.000e+00, rank = [9, 4]
# = swp=1 fwd finish, max_dx=1.000e+00, max_rank = 15
# = swp=2 core <6, dx=0.000e+00, rank = [4, 1]
# = swp=2 core <5, dx=1.778e-10, rank = [9, 4]
# = swp=2 core <4, dx=8.745e-09, rank = [15, 9]
# = swp=2 core <3, dx=1.211e-07, rank = [18, 15]
# = swp=2 core <2, dx=2.891e-06, rank = [20, 18]
# = swp=2 core <1, dx=1.092e-04, rank = [20, 20]
# = swp=3 core 0, max_dx=1.092e-04, max_rank = 20
# = swp=3 core 1>, dx=9.279e-06, rank = [25, 25]
# = swp=3 core 2>, dx=6.717e-06, rank = [25, 23]
# = swp=3 core 3>, dx=1.268e-06, rank = [23, 19]
# = swp=3 core 4>, dx=7.376e-08, rank = [19, 10]
# = swp=3 core 5>, dx=1.602e-09, rank = [10, 4]
# = swp=3 fwd finish, max_dx=9.279e-06, max_rank = 25

# %%
fig, ax = plt.subplots()

ax.plot(v_arr, err_standard, label='standard')
ax.plot(v_arr, err_lstsq, label='lstsq')

ax.set_xlabel('convection')
ax.set_ylabel('RMS l2 error')
# ax.set_xscale('log')
ax.set_yscale('log')
ax.legend()

ax.set_title('random_init=10, kickrank=5, 3 iterations')
# Out:
# Text(0.5, 1.0, 'random_init=10, kickrank=5, 3 iterations')
